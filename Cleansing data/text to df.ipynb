# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Rspse/Downloads/FGT1KC3912800175.tlog.1637680208.csv.log",dtype=object)

# %%
df
# Out:
#        itime=1637680208  date=2021-11-23  time=19:10:02  \
# 0      itime=1637680208  date=2021-11-23  time=19:10:02
# 1      itime=1637680208  date=2021-11-23  time=19:10:02
# 2      itime=1637680208  date=2021-11-23  time=19:10:02
# 3      itime=1637680208  date=2021-11-23  time=19:10:02
# 4      itime=1637680208  date=2021-11-23  time=19:10:03
# ...                 ...              ...            ...
# 98704  itime=1637697581  date=2021-11-23  time=23:59:36
# 98705  itime=1637697581  date=2021-11-23  time=23:59:37
# 98706  itime=1637697581  date=2021-11-23  time=23:59:39
# 98707  itime=1637697581  date=2021-11-23  time=23:59:39
# 98708  itime=1637697581  date=2021-11-23  time=23:59:41
#
#        devid=FGT1KC3912800175  vd=BTA-PER  type="traffic"  subtype="forward"  \
# 0      devid=FGT1KC3912800175  vd=BTA-PER  type="traffic"  subtype="forward"
# 1      devid=FGT1KC3912800175  vd=BTA-PER  type="traffic"    subtype="local"
# ...

# %%
a = 'itime=1637697581'

# %%
a.split('=')
# Out:
# ['itime', '1637697581']

# %%
df.columns
# Out:
# Index(['itime=1637680208', 'date=2021-11-23', 'time=19:10:02',
#        'devid=FGT1KC3912800175', 'vd=BTA-PER', 'type="traffic"',
#        'subtype="forward"', 'action="close"', 'Unnamed: 8', 'Unnamed: 9',
#        'appcat="unscanned"', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'devname=SBGH-HQUTM01',
#        'Unnamed: 22', 'Unnamed: 23', 'dstcountry="Reserved"', 'Unnamed: 25',
#        'dstintf="BTA-Core0"', 'dstintfrole="undefined"', 'dstip=172.16.4.208',
#        'Unnamed: 29', 'Unnamed: 30', 'dstport=9001', 'Unnamed: 32',
#        'dtime=1637694602', 'duration=19', 'eventtime=1637680202',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'idseq=180065435981447168',
#        'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'level="notice"',
#        'logid="0000000013"', 'logver=56', 'Unnamed: 46', 'Unnamed: 47',
# ...

# %%
df
# Out:
#        itime=1637680208  date=2021-11-23  time=19:10:02  \
# 0      itime=1637680208  date=2021-11-23  time=19:10:02
# 1      itime=1637680208  date=2021-11-23  time=19:10:02
# 2      itime=1637680208  date=2021-11-23  time=19:10:02
# 3      itime=1637680208  date=2021-11-23  time=19:10:02
# 4      itime=1637680208  date=2021-11-23  time=19:10:03
# ...                 ...              ...            ...
# 98704  itime=1637697581  date=2021-11-23  time=23:59:36
# 98705  itime=1637697581  date=2021-11-23  time=23:59:37
# 98706  itime=1637697581  date=2021-11-23  time=23:59:39
# 98707  itime=1637697581  date=2021-11-23  time=23:59:39
# 98708  itime=1637697581  date=2021-11-23  time=23:59:41
#
#        devid=FGT1KC3912800175  vd=BTA-PER  type="traffic"  subtype="forward"  \
# 0      devid=FGT1KC3912800175  vd=BTA-PER  type="traffic"  subtype="forward"
# 1      devid=FGT1KC3912800175  vd=BTA-PER  type="traffic"    subtype="local"
# ...

# %%
col =[]
for i in df.columns:
    for j in df[i]:
        try:
            if j is np.nan:
                continue
            else:
                new = j.split('=')[0]
                if new not in col:
                    col.append(new)
                    break
        except:
            np.nan

# %%
df.columns = col

# %%
df
# Out:
#                   itime             date           time  \
# 0      itime=1637680208  date=2021-11-23  time=19:10:02
# 1      itime=1637680208  date=2021-11-23  time=19:10:02
# 2      itime=1637680208  date=2021-11-23  time=19:10:02
# 3      itime=1637680208  date=2021-11-23  time=19:10:02
# 4      itime=1637680208  date=2021-11-23  time=19:10:03
# ...                 ...              ...            ...
# 98704  itime=1637697581  date=2021-11-23  time=23:59:36
# 98705  itime=1637697581  date=2021-11-23  time=23:59:37
# 98706  itime=1637697581  date=2021-11-23  time=23:59:39
# 98707  itime=1637697581  date=2021-11-23  time=23:59:39
# 98708  itime=1637697581  date=2021-11-23  time=23:59:41
#
#                         devid          vd            type            subtype  \
# 0      devid=FGT1KC3912800175  vd=BTA-PER  type="traffic"  subtype="forward"
# 1      devid=FGT1KC3912800175  vd=BTA-PER  type="traffic"    subtype="local"
# ...

# %%
for i in df.columns:
    cols=[]
    for j in df[i]:
        if j is np.nan:
            cols.append(np.nan)
        else:
            new = j.split('=')[1]
            cols.append(new)
    df[i] = cols

# %%
df
# Out:
#             itime        date      time             devid       vd       type  \
# 0      1637680208  2021-11-23  19:10:02  FGT1KC3912800175  BTA-PER  "traffic"
# 1      1637680208  2021-11-23  19:10:02  FGT1KC3912800175  BTA-PER  "traffic"
# 2      1637680208  2021-11-23  19:10:02  FGT1KC3912800175  BTA-PER  "traffic"
# 3      1637680208  2021-11-23  19:10:02  FGT1KC3912800175  BTA-PER  "traffic"
# 4      1637680208  2021-11-23  19:10:03  FGT1KC3912800175  BTA-PER  "traffic"
# ...           ...         ...       ...               ...      ...        ...
# 98704  1637697581  2021-11-23  23:59:36  FGT1KC3912800175  BTA-PER  "traffic"
# 98705  1637697581  2021-11-23  23:59:37  FGT1KC3912800175  BTA-PER  "traffic"
# 98706  1637697581  2021-11-23  23:59:39  FGT1KC3912800175  BTA-PER  "traffic"
# 98707  1637697581  2021-11-23  23:59:39  FGT1KC3912800175  BTA-PER  "traffic"
# 98708  1637697581  2021-11-23  23:59:41  FGT1KC3912800175  BTA-PER  "traffic"
#
# ...
